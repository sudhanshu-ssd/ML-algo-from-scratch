# %%
import numpy as np

# %%
class kmeans:
    def __init__(self,n_clusters,max_iter=100):
        self.n_clusters=n_clusters
        self.max_iter=max_iter
        self.centroids=None

    def fit(self,X):
        nsamples,nfeatures=X.shape
        indx=np.random.choice(nsamples,size=self.n_clusters,replace=False)
        self.centroids=X[indx]
                
        for _ in range(self.max_iter):
            sample_centriod_idx=[]
            for i in range(X.shape[0]):
                d=[]
                for j in range(self.centroids.shape[0]):
                    distance=np.linalg.norm(X[i]-self.centroids[j])
                    d.append(distance)
                sample_centroid_idx.append(np.argmin(d))

            for i in range(self.centroids.shape[0]):
                points_cluster=[]
                for j in range(X.shape[0]):
                    if sample_centroid_idx[j]==i:
                        points_clustere.append(X[j])


                if points_clusters:
                    self.centroids[i]=np.mean(points_cluster,axis=0)
                        
                    
                
                
                
                    # STILLL NEEED  PREDICT FUNCTION YOU DUMBFUCK PIECE OF SHIT
